# %%
#importing libraries
import warnings
warnings.filterwarnings("ignore")

import pandas as pd #dataframes 
import numpy as np #linear algebra
import seaborn as sns #visualization
sns.set(color_codes=True)

import scipy.stats as stats #statistical resources

import matplotlib.pyplot as plt #visualisation 
# %matplotlib inline

# %% [markdown]
# ## Importing csv file containing Planning Permissions for New Houses and Apartments - Ireland

# %%
df1 = pd.read_csv("Planning Permissions_NHA.csv", index_col="Year")

# %%
df1.head(20)
# Out:
#      STATISTIC               Statistic Label  TLIST(A1)  C01912V02351  \
# Year
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
# 1975  BHA12C01  Planning Permissions Granted       1975            11
#
#      Type of Dwelling C02196V04140     Region and County    UNIT VALUE
# Year
# 1975           Houses            -                 State  Number   NaN
# 1975           Houses         IE04  Northern and Western  Number   NaN
# 1975           Houses        IE041                Border  Number   NaN
# 1975           Houses      IE04128               Leitrim  Number   NaN
# 1975           Houses      IE04131                 Sligo  Number   NaN
# 1975           Houses      IE04132                 Cavan  Number   NaN
# 1975           Houses      IE04133               Donegal  Number   NaN
# 1975           Houses      IE04134              Monaghan  Number   NaN
# 1975           Houses        IE042                  West  Number   NaN
# 1975           Houses      IE04225                Galway  Number   NaN
# 1975           Houses      IE04226           Galway City  Number   NaN
# 1975           Houses      IE04229                  Mayo  Number   NaN
# 1975           Houses      IE04230             Roscommon  Number   NaN
# 1975           Houses         IE05              Southern  Number   NaN
# 1975           Houses        IE051              Mid-West  Number   NaN
# 1975           Houses      IE05116                 Clare  Number   NaN
# 1975           Houses      IE05118              Limerick  Number   NaN
# 1975           Houses      IE05122             Tipperary  Number   NaN
# 1975           Houses        IE052            South-East  Number   NaN
# 1975           Houses      IE05201                Carlow  Number   NaN

# %%
df1.tail()
# Out:
#      STATISTIC              Statistic Label  TLIST(A1)  C01912V02351  \
# Year
# 2022  BHA12C04  Average Floor Area per Unit       2022           102
# 2022  BHA12C04  Average Floor Area per Unit       2022           102
# 2022  BHA12C04  Average Floor Area per Unit       2022           102
# 2022  BHA12C04  Average Floor Area per Unit       2022           102
# 2022  BHA12C04  Average Floor Area per Unit       2022           102
#
#               Type of Dwelling C02196V04140 Region and County       UNIT VALUE
# Year
# 2022  Private flats/apartments        IE063           Midland  Sq Metres    81
# 2022  Private flats/apartments      IE06308             Laois  Sq Metres    67
# 2022  Private flats/apartments      IE06309          Longford  Sq Metres    71
# 2022  Private flats/apartments      IE06312            Offaly  Sq Metres    80
# 2022  Private flats/apartments      IE06313         Westmeath  Sq Metres    82

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33024 entries, 1975 to 2022
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   STATISTIC          33024 non-null  object
#  1   Statistic Label    33024 non-null  object
#  2   TLIST(A1)          33024 non-null  int64
#  3   C01912V02351       33024 non-null  int64
#  4   Type of Dwelling   33024 non-null  object
#  5   C02196V04140       33024 non-null  object
#  6   Region and County  33024 non-null  object
#  7   UNIT               33024 non-null  object
#  8   VALUE              3766 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 2.5+ MB

# %%
df1.describe(include=object)
# Out:
#        STATISTIC               Statistic Label Type of Dwelling C02196V04140  \
# count      33024                         33024            33024        33024
# unique         4                             4                4           43
# top     BHA12C01  Planning Permissions Granted           Houses            -
# freq        8256                          8256             8256          768
#
#        Region and County    UNIT VALUE
# count              33024   33024  3766
# unique                43       3  1125
# top                State  Number    12
# freq                 768   16512    30

# %%
df1.isna()
# Out:
#       STATISTIC  Statistic Label  TLIST(A1)  C01912V02351  Type of Dwelling  \
# Year
# 1975      False            False      False         False             False
# 1975      False            False      False         False             False
# 1975      False            False      False         False             False
# 1975      False            False      False         False             False
# 1975      False            False      False         False             False
# ...         ...              ...        ...           ...               ...
# 2022      False            False      False         False             False
# 2022      False            False      False         False             False
# 2022      False            False      False         False             False
# 2022      False            False      False         False             False
# 2022      False            False      False         False             False
#
#       C02196V04140  Region and County   UNIT  VALUE
# Year
# 1975         False              False  False   True
# 1975         False              False  False   True
# 1975         False              False  False   True
# 1975         False              False  False   True
# 1975         False              False  False   True
# ...            ...                ...    ...    ...
# 2022         False              False  False  False
# 2022         False              False  False  False
# 2022         False              False  False  False
# 2022         False              False  False  False
# 2022         False              False  False  False
#
# [33024 rows x 9 columns]

# %%
#drop columns with information that are not required for analysis
df1.drop(['STATISTIC','TLIST(A1)', 'C02196V04140','C01912V02351' ], inplace=True, axis=1)

# %%
#df1['Year'] = df1['Year'].astype(int)

# %%
print(df1.dtypes)
# Out:
# Statistic Label       object
# Type of Dwelling      object
# Region and County     object
# UNIT                  object
# VALUE                float64
# dtype: object

# %%
df1.dropna(["VALUE"]=="Nan", inplace=True)

# %%
#df1.set_index("Year", inplace=True)

# %%
df1['VALUE'] = pd.to_numeric(df1['VALUE'], errors='coerce')

# %%
df1
# Out:
#                    Statistic Label          Type of Dwelling  \
# Year
# 1977  Planning Permissions Granted                    Houses
# 1977  Planning Permissions Granted  Private flats/apartments
# 1978  Planning Permissions Granted                    Houses
# 1978  Planning Permissions Granted  Private flats/apartments
# 1979  Planning Permissions Granted                    Houses
# ...                            ...                       ...
# 2022   Average Floor Area per Unit  Private flats/apartments
# 2022   Average Floor Area per Unit  Private flats/apartments
# 2022   Average Floor Area per Unit  Private flats/apartments
# 2022   Average Floor Area per Unit  Private flats/apartments
# 2022   Average Floor Area per Unit  Private flats/apartments
#
#      Region and County       UNIT    VALUE
# Year
# 1977             State     Number  12390.0
# 1977             State     Number     49.0
# 1978             State     Number  13870.0
# 1978             State     Number     61.0
# 1979             State     Number  15897.0
# ...                ...        ...      ...
# 2022           Midland  Sq Metres     81.0
# 2022             Laois  Sq Metres     67.0
# 2022          Longford  Sq Metres     71.0
# 2022            Offaly  Sq Metres     80.0
# 2022         Westmeath  Sq Metres     82.0
#
# [3762 rows x 5 columns]

# %%
print(df1.dtypes)
# Out:
# Statistic Label       object
# Type of Dwelling      object
# Region and County     object
# UNIT                  object
# VALUE                float64
# dtype: object

# %%
df1.describe()
# Out:
#               VALUE
# count   3762.000000
# mean    1054.758426
# std     4442.986173
# min        0.000000
# 25%       60.050000
# 50%      141.500000
# 75%      330.500000
# max    75650.000000

# %%
sns.pairplot(df1)

# %%
#group by year
grouped = df1.groupby(level=0).sum()

# %%
df=grouped_df.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 df=grouped_df.to_frame()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:987, in GroupBy.__getattr__(self, attr)
#     984 if attr in self.obj:
#     985     return self[attr]
# --> 987 raise AttributeError(
#     988     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     989 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'to_frame'

# %%
#find out what are the unique categories inside "statistic label" to separate into different units

categories = df1['Statistic Label'].unique()
print(categories)
# Out:
# ['Planning Permissions Granted' 'Units for which Permission Granted'
#  'Total Floor Area for which Permission Granted'
#  'Average Floor Area per Unit']

# %%
df=df1.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 df=df1.to_frame()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
sns.displot(df1["Statistic Label"],x="Year")

# %%
grouped = df1.groupby('Statistic Label')
display(grouped)

# %%
grouped

# %%
new_df = pd.read_csv("Planning Permissions_NRB.csv", index_col="Year")

# %%
new_df.drop(["STATISTIC", "TLIST(A1)","C01912V02351", "C01921V02511"], inplace=True, axis=1)

# %%
nbr_df=new_df
nbr_df
# Out:
#                                     Statistic Label  \
# Year
# 2001                   Planning Permissions Granted
# 2001                   Planning Permissions Granted
# 2001                   Planning Permissions Granted
# 2001                   Planning Permissions Granted
# 2001                   Planning Permissions Granted
# ...                                             ...
# 2022  Total Floor Area for which Permission Granted
# 2022  Total Floor Area for which Permission Granted
# 2022  Total Floor Area for which Permission Granted
# 2022  Total Floor Area for which Permission Granted
# 2022  Total Floor Area for which Permission Granted
#
#                        Type of Non Residential Building  \
# Year
# 2001                      All non residential buildings
# 2001                      All non residential buildings
# 2001                      All non residential buildings
# 2001                      All non residential buildings
# 2001  Buildings for agriculture, forestry, horticult...
# ...                                                 ...
# 2022  Office development, buildings for financing an...
# 2022                                             Creche
# 2022                                             Creche
# 2022                                             Creche
# 2022                                             Creche
#
#                        Type of Construction           UNIT VALUE
# Year
# 2001              All types of construction         Number  7553
# 2001                       New construction         Number  3461
# 2001                             Extensions         Number  2400
# 2001  Alteration, conversion and renovation         Number  1692
# 2001              All types of construction         Number  1223
# ...                                     ...            ...   ...
# 2022  Alteration, conversion and renovation  000 Sq Metres     0
# 2022              All types of construction  000 Sq Metres    21
# 2022                       New construction  000 Sq Metres    19
# 2022                             Extensions  000 Sq Metres     1
# 2022  Alteration, conversion and renovation  000 Sq Metres     0
#
# [2640 rows x 5 columns]
